# %%
from gather_results import gather_val_res, plot_confusion_matrix
# %load_ext autoreload
# %autoreload 2

# %%
df_agg_res, cm_rr_lstm, cm_seq, classes = gather_val_res()
# Out:
# /home/wenhao/Jupyter/wenhao/workspace/cpsc2021/working_dir/val_res
# log file path is set "/home/wenhao/Jupyter/wenhao/workspace/cpsc2021/CPSC2021Reader-CPSC2021.log"
# levels of c_handler and f_handler are set DEBUG

# %%
cls_cols = ["record", "truth_cls", "final_pred_cls", "final_pred_new_cls", "rr_pred_cls", "seq_pred_cls",]

# %%
df_agg_res
# Out:
#          record                             truth  \
# 0    data_95_10                      [[0, 72924]]
# 1     data_33_7                      [[0, 86559]]
# 2    data_68_22  [[19235, 20282], [28917, 36981]]
# 3    data_33_19                     [[0, 174386]]
# 4     data_75_2                       [[0, 8363]]
# ..          ...                               ...
# 287   data_10_1                     [[0, 110368]]
# 288  data_93_13                                []
# 289  data_22_11                     [[0, 541137]]
# 290   data_55_6                                []
# 291  data_68_16                      [[0, 10200]]
#
#                            final_pred                    final_pred_new  \
# 0                        [[0, 72924]]                      [[0, 72924]]
# 1                        [[0, 86559]]                      [[0, 86559]]
# 2    [[19232, 20455], [28844, 36948]]  [[19232, 20455], [28844, 36948]]
# ...

# %%
df_agg_res[df_agg_res.truth_cls!=df_agg_res.final_pred_cls].reset_index(drop=True)[cls_cols]
# Out:
#         record truth_cls final_pred_cls final_pred_new_cls rr_pred_cls  \
# 0     data_1_8         N            AFp                  N         AFp
# 1     data_1_7         N            AFp                  N         AFp
# 2    data_68_2       AFp            AFf                AFf         AFf
# 3    data_72_7         N            AFp                  N         AFp
# 4     data_1_3         N            AFp                  N         AFp
# 5    data_85_2       AFp            AFf                AFf           N
# 6     data_1_4         N            AFp                  N         AFp
# 7     data_1_5         N            AFp                  N         AFp
# 8     data_1_6         N            AFp                  N         AFp
# 9    data_72_4         N            AFp                  N         AFp
# 10   data_72_2         N            AFp                AFp         AFp
# 11    data_1_2         N            AFp                  N         AFp
# ...

# %%
df_agg_res[df_agg_res.truth_cls!=df_agg_res.final_pred_new_cls].reset_index(drop=True)
# Out:
#        record              truth  \
# 0   data_68_2      [[0, 597119]]
# 1   data_98_3   [[24543, 25003]]
# 2   data_85_2       [[0, 12951]]
# 3   data_72_2                 []
# 4  data_68_15  [[36042, 539489]]
# 5    data_1_1                 []
# 6   data_72_1                 []
#
#                                      final_pred  \
# 0                                 [[0, 648619]]
# 1                              [[24636, 25148]]
# 2                                  [[0, 15359]]
# 3  [[0, 23071], [25144, 27599], [31200, 38999]]
# 4                                 [[0, 539488]]
# 5                                 [[0, 393082]]
# 6                                  [[0, 39439]]
#
#                                  final_pred_new  \
# 0                                 [[0, 648619]]
# 1                                            []
# 2                                  [[0, 15359]]
# 3  [[0, 23071], [25144, 27599], [31200, 38999]]
# 4                                 [[0, 539488]]
# ...

# %%
df_agg_res[df_agg_res.truth_cls!=df_agg_res.rr_pred_cls].reset_index(drop=True)
# Out:
#         record              truth  \
# 0     data_1_8                 []
# 1     data_1_7                 []
# 2    data_68_2      [[0, 597119]]
# 3    data_72_7                 []
# 4     data_1_3                 []
# 5    data_85_2       [[0, 12951]]
# 6     data_1_4                 []
# 7     data_1_5                 []
# 8     data_1_6                 []
# 9    data_72_4                 []
# 10   data_72_2                 []
# 11    data_1_2                 []
# 12  data_68_15  [[36042, 539489]]
# 13    data_1_1                 []
# 14   data_72_1                 []
# 15  data_43_10                 []
# 16  data_34_17                 []
#
#                                            final_pred  \
# 0   [[14580, 18716], [21820, 23092], [28292, 30128...
# 1   [[101548, 102288], [160044, 160828], [187200, ...
# 2                                       [[0, 648619]]
# 3                                     [[9900, 10572]]
# 4   [[62988, 64092], [79876, 80628], [110052, 1112...
# ...

# %%
df_agg_res[df_agg_res.truth_cls!=df_agg_res.seq_pred_cls].reset_index(drop=True)
# Out:
#         record             truth  \
# 0    data_98_3  [[24543, 25003]]
# 1    data_85_2      [[0, 12951]]
# 2   data_95_15      [[0, 33266]]
# 3    data_10_8     [[0, 656008]]
# 4    data_10_7     [[0, 150006]]
# 5   data_10_11     [[0, 129094]]
# 6   data_10_10     [[0, 570195]]
# 7   data_10_12      [[0, 99624]]
# 8    data_10_9      [[0, 70326]]
# 9    data_10_6     [[0, 305652]]
# 10   data_72_2                []
# 11  data_91_13     [[0, 137660]]
# 12  data_10_13     [[0, 133842]]
# 13   data_72_1                []
# 14    data_1_9                []
# 15   data_10_3      [[0, 99130]]
# 16   data_10_1     [[0, 110368]]
#
#                                            final_pred  \
# 0                                    [[24636, 25148]]
# 1                                        [[0, 15359]]
# 2                                        [[0, 33266]]
# 3                                       [[0, 656008]]
# 4                                       [[0, 150006]]
# ...

# %%
df_agg_res[(df_agg_res.truth_cls!="N") & (df_agg_res.seq_pred_cls=="N")].reset_index(drop=True)
# Out:
#       record             truth        final_pred final_pred_new  \
# 0  data_98_3  [[24543, 25003]]  [[24636, 25148]]             []
# 1  data_10_9      [[0, 70326]]      [[0, 70326]]   [[0, 70326]]
#
#             rr_pred seq_pred truth_cls final_pred_cls final_pred_new_cls  \
# 0  [[24636, 25148]]       []       AFp            AFp                  N
# 1      [[0, 70326]]       []       AFf            AFf                AFf
#
#   rr_pred_cls seq_pred_cls
# 0         AFp            N
# 1         AFf            N

# %%
df_agg_res[(df_agg_res.truth_cls!="AFf") & (df_agg_res.seq_pred_cls=="AFf")].reset_index(drop=True)
# Out:
#       record         truth    final_pred final_pred_new           rr_pred  \
# 0  data_85_2  [[0, 12951]]  [[0, 15359]]   [[0, 15359]]                []
# 1  data_72_1            []  [[0, 39439]]   [[0, 39439]]  [[38660, 39439]]
#
#        seq_pred truth_cls final_pred_cls final_pred_new_cls rr_pred_cls  \
# 0  [[0, 15359]]       AFp            AFf                AFf           N
# 1  [[0, 39439]]         N            AFf                AFf         AFp
#
#   seq_pred_cls
# 0          AFf
# 1          AFf

# %%
df_agg_res[(df_agg_res.truth_cls!="AFp") & (df_agg_res.seq_pred_cls=="AFp")].reset_index(drop=True)
# Out:
#         record          truth  \
# 0   data_95_15   [[0, 33266]]
# 1    data_10_8  [[0, 656008]]
# 2    data_10_7  [[0, 150006]]
# 3   data_10_11  [[0, 129094]]
# 4   data_10_10  [[0, 570195]]
# 5   data_10_12   [[0, 99624]]
# 6    data_10_6  [[0, 305652]]
# 7    data_72_2             []
# 8   data_91_13  [[0, 137660]]
# 9   data_10_13  [[0, 133842]]
# 10    data_1_9             []
# 11   data_10_3   [[0, 99130]]
# 12   data_10_1  [[0, 110368]]
#
#                                            final_pred  \
# 0                                        [[0, 33266]]
# 1                                       [[0, 656008]]
# 2                                       [[0, 150006]]
# 3                                       [[0, 129094]]
# 4                                       [[0, 570195]]
# 5                                        [[0, 99624]]
# 6                                       [[0, 305652]]
# 7        [[0, 23071], [25144, 27599], [31200, 38999]]
# ...

# %%
df_agg_res[(df_agg_res.truth_cls!="N") & (df_agg_res.rr_pred_cls=="N")].reset_index(drop=True)
# Out:
#       record         truth    final_pred final_pred_new rr_pred      seq_pred  \
# 0  data_85_2  [[0, 12951]]  [[0, 15359]]   [[0, 15359]]      []  [[0, 15359]]
#
#   truth_cls final_pred_cls final_pred_new_cls rr_pred_cls seq_pred_cls
# 0       AFp            AFf                AFf           N          AFf

# %%
df_agg_res[(df_agg_res.truth_cls!="AFf") & (df_agg_res.rr_pred_cls=="AFf")].reset_index(drop=True)
# Out:
#        record              truth     final_pred final_pred_new        rr_pred  \
# 0   data_68_2      [[0, 597119]]  [[0, 648619]]  [[0, 648619]]  [[0, 648619]]
# 1  data_68_15  [[36042, 539489]]  [[0, 539488]]  [[0, 539488]]  [[0, 539488]]
# 2    data_1_1                 []  [[0, 393082]]  [[0, 393082]]  [[0, 393082]]
#
#             seq_pred truth_cls final_pred_cls final_pred_new_cls rr_pred_cls  \
# 0      [[0, 597111]]       AFp            AFf                AFf         AFf
# 1  [[35576, 539488]]       AFp            AFf                AFf         AFf
# 2                 []         N            AFf                AFf         AFf
#
#   seq_pred_cls
# 0          AFp
# 1          AFp
# 2            N

# %%
df_agg_res[(df_agg_res.truth_cls!="AFp") & (df_agg_res.rr_pred_cls=="AFp")].reset_index(drop=True)
# Out:
#         record truth                                         final_pred  \
# 0     data_1_8    []  [[14580, 18716], [21820, 23092], [28292, 30128...
# 1     data_1_7    []  [[101548, 102288], [160044, 160828], [187200, ...
# 2    data_72_7    []                                    [[9900, 10572]]
# 3     data_1_3    []  [[62988, 64092], [79876, 80628], [110052, 1112...
# 4     data_1_4    []                                 [[218628, 220084]]
# 5     data_1_5    []  [[11732, 12356], [19460, 20188], [152452, 1533...
# 6     data_1_6    []  [[96732, 97484], [101068, 101940], [196548, 19...
# 7    data_72_4    []                     [[2900, 3792], [19980, 23124]]
# 8    data_72_2    []       [[0, 23071], [25144, 27599], [31200, 38999]]
# 9     data_1_2    []  [[0, 1204], [8724, 13700], [15004, 16116], [17...
# 10   data_72_1    []                                       [[0, 39439]]
# 11  data_43_10    []                               [[1345244, 1346396]]
# ...

# %%
df_agg_res[(df_agg_res.final_pred_cls!=df_agg_res.seq_pred_cls)].reset_index(drop=True)
# Out:
#         record              truth  \
# 0     data_1_8                 []
# 1     data_1_7                 []
# 2    data_68_2      [[0, 597119]]
# 3    data_98_3   [[24543, 25003]]
# 4    data_72_7                 []
# 5     data_1_3                 []
# 6     data_1_4                 []
# 7     data_1_5                 []
# 8     data_1_6                 []
# 9   data_95_15       [[0, 33266]]
# 10   data_72_4                 []
# 11   data_10_8      [[0, 656008]]
# 12   data_10_7      [[0, 150006]]
# 13  data_10_11      [[0, 129094]]
# 14  data_10_10      [[0, 570195]]
# 15  data_10_12       [[0, 99624]]
# 16   data_10_9       [[0, 70326]]
# 17   data_10_6      [[0, 305652]]
# 18  data_91_13      [[0, 137660]]
# 19    data_1_2                 []
# 20  data_10_13      [[0, 133842]]
# 21  data_68_15  [[36042, 539489]]
# 22    data_1_1                 []
# 23  data_43_10                 []
# 24  data_34_17                 []
# 25   data_10_3       [[0, 99130]]
# ...
